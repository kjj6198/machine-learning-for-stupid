# %%
# 建立範例用的方程式
import numpy as np

number_of_points = 500
x_point = []
y_point = []

a = 0.22
b = 0.78

for i in range(number_of_points):
    x = np.random.normal(0.0, 0.5)
    y = a * x + b + np.random.normal(0.0, 0.1)
    x_point.append([x])
    y_point.append([y])
    
import matplotlib.pyplot as plt

plt.plot(x_point, y_point, 'o', label = "Input Data")
plt.legend()
plt.show()

# %%
# 第二部 成本函數與梯度下降法
import tensorflow as tf
A = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))

y = A * x_point + b

# 成本函數是平均方差
cost_function = tf.reduce_mean(tf.square(y - y_point))
learning_rate = 0.5
optimizer = tf.train.GradientDescentOptimizer(learning_rate)

train = optimizer.minimize(cost_function)

model = tf.global_variables_initializer()

with tf.Session() as session:
    session.run(model)
    for step in range(0,100):
        if step % 10 == 0:
          session.run(train)
          plt.plot(x_point, y_point, 'o', label= "step={}".format(step))
          plt.plot(x_point, session.run(A) * x_point + session.run(b))
          plt.legend()
          plt.show()
# Out:
# WARNING:tensorflow:From <ipython-input-2-7c54c31e1d78>:15: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.

# %% [markdown]
# 這邊使用梯度下降法尋找誤差最小值，直線回慢慢地走到正確的位置。
